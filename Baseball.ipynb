# %%
import pandas as pd
import numpy as np
#import pandas_profiling

path = r"/Users/kevin.reilly/Library/CloudStorage/OneDrive-TheTradeDesk/repos/baseballdatabank/core/Batting.csv"
# 'r' is used to elminate the whitespace in the path.

df = pd.read_csv(path)

pop = len(df)
print ("Total records:")
print (pop)
print ("")
print ("The summary stats:")
df.describe()
# Out:
# Total records:
# 102816
#
# The summary stats:
#               yearID          stint              G             AB  \
# count  102816.000000  102816.000000  102816.000000  102816.000000
# mean     1964.262313       1.077838      51.343439     141.905511
# std        38.856297       0.284366      47.121658     184.654492
# min      1871.000000       1.000000       1.000000       0.000000
# 25%      1934.000000       1.000000      13.000000       4.000000
# 50%      1973.000000       1.000000      34.000000      49.000000
# 75%      1998.000000       1.000000      80.000000     231.000000
# max      2016.000000       5.000000     165.000000     716.000000
#
#                    R              H             2B             3B  \
# count  102816.000000  102816.000000  102816.000000  102816.000000
# mean       18.815544      37.139930       6.289167       1.293252
# std        28.242983      52.603757       9.662468       2.645770
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         4.000000       9.000000       1.000000       0.000000
# 75%        27.000000      58.000000       9.000000       1.000000
# max       192.000000     262.000000      67.000000      36.000000
#
#                   HR            RBI             SB            CS  \
# count  102816.000000  102392.000000  101516.000000  79360.000000
# mean        2.813599      17.003975       2.976821      1.226008
# std         6.304919      26.352011       7.717174      2.747377
# min         0.000000       0.000000       0.000000      0.000000
# 25%         0.000000       0.000000       0.000000      0.000000
# 50%         0.000000       3.000000       0.000000      0.000000
# 75%         2.000000      24.000000       2.000000      1.000000
# max        73.000000     191.000000     138.000000     42.000000
#
#                   BB            SO           IBB            HBP            SH  \
# count  102816.000000  94978.000000  66251.000000  100006.000000  96478.000000
# mean       13.067207     20.529712      1.105870       1.056057      2.299540
# std        20.746460     28.328542      2.780187       2.276251      4.241095
# min         0.000000      0.000000      0.000000       0.000000      0.000000
# 25%         0.000000      1.000000      0.000000       0.000000      0.000000
# 50%         3.000000      9.000000      0.000000       0.000000      0.000000
# 75%        18.000000     29.000000      1.000000       1.000000      3.000000
# max       232.000000    223.000000    120.000000      51.000000     67.000000
#
#                  SF          GIDP
# count  66782.000000  76706.000000
# mean       1.054101      2.981018
# std        1.961732      4.735153
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        1.000000      4.000000
# max       19.000000     36.000000

# %%
df['H'].describe()
# Out:
# count    102816.000000
# mean         37.139930
# std          52.603757
# min           0.000000
# 25%           0.000000
# 50%           9.000000
# 75%          58.000000
# max         262.000000
# Name: H, dtype: float64

# %% [markdown]
# # Selecting a Year
#
# Looking only for data on a single year.
#
# There are multiple ways to select dataframe rows based on a critira.
#
# `df[df.column_name == value]`
#
# `df.loc[df[columnname] == value]`
#
# * Determine how to select rows based on multiple criteria
# * Figure out how to add a column based on a calculation

# %%
yr = 2020

df_yr = df[df.yearID == yr]
df_yr
# Out:
# Empty DataFrame
# Columns: [playerID, yearID, stint, teamID, lgID, G, AB, R, H, 2B, 3B, HR, RBI, SB, CS, BB, SO, IBB, HBP, SH, SF, GIDP]
# Index: []
#
# [0 rows x 22 columns]

# %%
team = df.loc[df['teamID'] == 'NY1']

team
# Out:
#         playerID  yearID  stint teamID lgID   G   AB   R    H  2B  ...   RBI  \
# 1683   allenmy01    1883      1    NY1   NL   1    4   0    0   0  ...   1.0
# 1719   caskied01    1883      1    NY1   NL  95  383  47   91  11  ...  40.0
# 1722   clappjo01    1883      1    NY1   NL  20   73   6   13   0  ...   5.0
# 1726   connoro01    1883      1    NY1   NL  98  409  80  146  28  ...  50.0
# 1730   cramedi01    1883      1    NY1   NL   2    6   0    0   0  ...   0.0
# ...          ...     ...    ...    ...  ...  ..  ...  ..  ...  ..  ...   ...
# 39275  thomava01    1957      1    NY1   NL  88  241  30   60  10  ...  31.0
# 39278  thomsbo01    1957      2    NY1   NL  81  215  24   52   7  ...  38.0
# 39303  virgioz01    1957      1    NY1   NL  96  226  26   53   0  ...  24.0
# 39312  westrwe01    1957      1    NY1   NL  63   91   4   15   1  ...   2.0
# 39331  worthal01    1957      1    NY1   NL  55   40   0    4   0  ...   3.0
#
#         SB   CS  BB    SO  IBB  HBP   SH   SF  GIDP
# 1683   NaN  NaN   0   2.0  NaN  NaN  NaN  NaN   NaN
# 1719   NaN  NaN  14  25.0  NaN  NaN  NaN  NaN   NaN
# 1722   NaN  NaN   5   4.0  NaN  NaN  NaN  NaN   NaN
# 1726   NaN  NaN  25  16.0  NaN  NaN  NaN  NaN   NaN
# 1730   NaN  NaN   1   5.0  NaN  NaN  NaN  NaN   NaN
# ...    ...  ...  ..   ...  ...  ...  ...  ...   ...
# 39275  0.0  0.0  16  29.0  1.0  1.0  2.0  2.0   5.0
# 39278  1.0  2.0  19  39.0  2.0  0.0  2.0  1.0   2.0
# 39303  2.0  3.0  14  27.0  1.0  0.0  0.0  1.0   8.0
# 39312  0.0  1.0  10  24.0  1.0  1.0  1.0  0.0   1.0
# 39331  0.0  0.0   1  10.0  0.0  1.0  1.0  0.0   1.0
#
# [2327 rows x 22 columns]

# %%
df_yr["BA"] = df_yr.H / df_yr.AB

df_yr
# Out:
# Empty DataFrame
# Columns: [playerID, yearID, stint, teamID, lgID, G, AB, R, H, 2B, 3B, HR, RBI, SB, CS, BB, SO, IBB, HBP, SH, SF, GIDP, BA]
# Index: []
#
# [0 rows x 23 columns]

# %%
df.RBI.describe()
# Out:
# count    102392.000000
# mean         17.003975
# std          26.352011
# min           0.000000
# 25%           0.000000
# 50%           3.000000
# 75%          24.000000
# max         191.000000
# Name: RBI, dtype: float64

# %%
rbi = df.RBI.max()
rbi
# Out:
# 191.0

# %%
df.HR.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
fifty = df[df.HR > 50]
#fifty[['playerID', 'yearID', 'HR']].sort_values('HR',ascending=False)
fifty
# Out:
#         playerID  yearID  stint teamID lgID    G   AB    R    H  2B  ...  \
# 18519   ruthba01    1920      1    NYA   AL  142  457  158  172  36  ...
# 19039   ruthba01    1921      1    NYA   AL  152  540  177  204  44  ...
# 22256   ruthba01    1927      1    NYA   AL  151  540  158  192  29  ...
# 22786   ruthba01    1928      1    NYA   AL  154  536  163  173  29  ...
# 23965  wilsoha01    1930      1    CHN   NL  155  585  146  208  35  ...
# 24639   foxxji01    1932      1    PHA   AL  154  585  151  213  33  ...
# 27752  greenha01    1938      1    DET   AL  155  556  144  175  23  ...
# 32987  kinerra01    1947      1    PIT   NL  152  565  118  177  23  ...
# 33089   mizejo01    1947      1    NY1   NL  154  586  137  177  26  ...
# 34139  kinerra01    1949      1    PIT   NL  152  549  116  170  19  ...
# 37819   mayswi01    1955      1    NY1   NL  152  580  123  185  18  ...
# 38452  mantlmi01    1956      1    NYA   AL  150  533  132  188  22  ...
# 41659  mantlmi01    1961      1    NYA   AL  153  514  132  163  16  ...
# 41661  marisro01    1961      1    NYA   AL  161  590  132  159  16  ...
# 44642   mayswi01    1965      1    SFN   NL  157  558  118  177  21  ...
# 54746  fostege01    1977      1    CIN   NL  158  615  124  197  31  ...
# 67707  fieldce01    1990      1    DET   AL  159  573  104  159  25  ...
# 74863  mcgwima01    1996      1    OAK   AL  130  423  104  132  21  ...
# 75819  griffke02    1997      1    SEA   AL  157  608  125  185  34  ...
# 77063  griffke02    1998      1    SEA   AL  161  633  120  180  33  ...
# 77389  mcgwima01    1998      1    SLN   NL  155  509  130  152  21  ...
# 77736   sosasa01    1998      1    CHN   NL  159  643  134  198  20  ...
# 78705  mcgwima01    1999      1    SLN   NL  153  521  118  145  21  ...
# 79053   sosasa01    1999      1    CHN   NL  162  625  114  180  24  ...
# 80752  bondsba01    2001      1    SFN   NL  153  476  129  156  32  ...
# 81079  gonzalu01    2001      1    ARI   NL  162  609  128  198  36  ...
# 81673  rodrial01    2001      1    TEX   AL  162  632  133  201  34  ...
# 81770   sosasa01    2001      1    CHN   NL  160  577  146  189  34  ...
# 82996  rodrial01    2002      1    TEX   AL  162  624  125  187  27  ...
# 83151  thomeji01    2002      1    CLE   AL  147  480  101  146  19  ...
# 86607  jonesan01    2005      1    ATL   NL  160  586   95  154  24  ...
# 87887  howarry01    2006      1    PHI   NL  159  581  104  182  25  ...
# 88231  ortizda01    2006      1    BOS   AL  151  558  115  160  29  ...
# 89768  rodrial01    2007      1    NYA   AL  158  583  143  183  31  ...
# 92915  bautijo02    2010      1    TOR   AL  161  569  109  148  35  ...
# 97312  davisch02    2013      1    BAL   AL  160  584  103  167  42  ...
#
#          RBI    SB    CS   BB     SO   IBB   HBP    SH    SF  GIDP
# 18519  137.0  14.0  14.0  150   80.0   NaN   3.0   5.0   NaN   NaN
# 19039  171.0  17.0  13.0  145   81.0   NaN   4.0   4.0   NaN   NaN
# 22256  164.0   7.0   6.0  137   89.0   NaN   0.0  14.0   NaN   NaN
# 22786  142.0   4.0   5.0  137   87.0   NaN   3.0   8.0   NaN   NaN
# 23965  191.0   3.0   NaN  105   84.0   NaN   1.0  18.0   NaN   NaN
# 24639  169.0   3.0   7.0  116   96.0   NaN   0.0   0.0   NaN   NaN
# 27752  146.0   7.0   5.0  119   92.0   NaN   3.0   3.0   NaN   NaN
# 32987  127.0   1.0   NaN   98   81.0   NaN   2.0   1.0   NaN  12.0
# 33089  138.0   2.0   NaN   74   42.0   NaN   4.0   0.0   NaN   6.0
# 34139  127.0   6.0   NaN  117   61.0   NaN   1.0   0.0   NaN  10.0
# 37819  127.0  24.0   4.0   79   60.0  13.0   4.0   0.0   7.0  12.0
# 38452  130.0  10.0   1.0  112   99.0   6.0   2.0   1.0   4.0   4.0
# 41659  128.0  12.0   1.0  126  112.0   9.0   0.0   1.0   5.0   2.0
# 41661  142.0   0.0   0.0   94   67.0   0.0   7.0   0.0   7.0  16.0
# 44642  112.0   9.0   4.0   76   71.0  16.0   0.0   2.0   2.0  11.0
# 54746  149.0   6.0   4.0   61  107.0  10.0   5.0   0.0   8.0  17.0
# 67707  132.0   0.0   1.0   90  182.0  11.0   5.0   0.0   5.0  15.0
# 74863  113.0   0.0   0.0  116  112.0  16.0   8.0   0.0   1.0  14.0
# 75819  147.0  15.0   4.0   76  121.0  23.0   8.0   0.0  12.0  12.0
# 77063  146.0  20.0   5.0   76  121.0  11.0   7.0   0.0   4.0  14.0
# 77389  147.0   1.0   0.0  162  155.0  28.0   6.0   0.0   4.0   8.0
# 77736  158.0  18.0   9.0   73  171.0  14.0   1.0   0.0   5.0  20.0
# 78705  147.0   0.0   0.0  133  141.0  21.0   2.0   0.0   5.0  12.0
# 79053  141.0   7.0   8.0   78  171.0   8.0   3.0   0.0   6.0  17.0
# 80752  137.0  13.0   3.0  177   93.0  35.0   9.0   0.0   2.0   5.0
# 81079  142.0   1.0   1.0  100   83.0  24.0  14.0   0.0   5.0  14.0
# 81673  135.0  18.0   3.0   75  131.0   6.0  16.0   0.0   9.0  17.0
# 81770  160.0   0.0   2.0  116  153.0  37.0   6.0   0.0  12.0   6.0
# 82996  142.0   9.0   4.0   87  122.0  12.0  10.0   0.0   4.0  14.0
# 83151  118.0   1.0   2.0  122  139.0  18.0   5.0   0.0   6.0   5.0
# 86607  128.0   5.0   3.0   64  112.0  13.0  15.0   0.0   7.0  19.0
# 87887  149.0   0.0   0.0  108  181.0  37.0   9.0   0.0   6.0   7.0
# 88231  137.0   1.0   0.0  119  117.0  23.0   4.0   0.0   5.0  12.0
# 89768  156.0  24.0   4.0   95  120.0  11.0  21.0   0.0   9.0  15.0
# 92915  124.0   9.0   2.0  100  116.0   2.0  10.0   0.0   4.0  10.0
# 97312  138.0   4.0   1.0   72  199.0  12.0  10.0   0.0   7.0   4.0
#
# [36 rows x 22 columns]

# %%
fifty["rank"] = fifty.groupby("playerID")["HR"].rank("dense", ascending=False)
fifty
# Out:
# /var/folders/5n/gszdkkrj46jb_dz53wsz7hvr0000gq/T/ipykernel_2463/3277841179.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fifty["rank"] = fifty.groupby("playerID")["HR"].rank("dense", ascending=False)
#         playerID  yearID  stint teamID lgID    G   AB    R    H  2B  ...  \
# 18519   ruthba01    1920      1    NYA   AL  142  457  158  172  36  ...
# 19039   ruthba01    1921      1    NYA   AL  152  540  177  204  44  ...
# 22256   ruthba01    1927      1    NYA   AL  151  540  158  192  29  ...
# 22786   ruthba01    1928      1    NYA   AL  154  536  163  173  29  ...
# 23965  wilsoha01    1930      1    CHN   NL  155  585  146  208  35  ...
# 24639   foxxji01    1932      1    PHA   AL  154  585  151  213  33  ...
# 27752  greenha01    1938      1    DET   AL  155  556  144  175  23  ...
# 32987  kinerra01    1947      1    PIT   NL  152  565  118  177  23  ...
# 33089   mizejo01    1947      1    NY1   NL  154  586  137  177  26  ...
# 34139  kinerra01    1949      1    PIT   NL  152  549  116  170  19  ...
# 37819   mayswi01    1955      1    NY1   NL  152  580  123  185  18  ...
# 38452  mantlmi01    1956      1    NYA   AL  150  533  132  188  22  ...
# 41659  mantlmi01    1961      1    NYA   AL  153  514  132  163  16  ...
# 41661  marisro01    1961      1    NYA   AL  161  590  132  159  16  ...
# 44642   mayswi01    1965      1    SFN   NL  157  558  118  177  21  ...
# 54746  fostege01    1977      1    CIN   NL  158  615  124  197  31  ...
# 67707  fieldce01    1990      1    DET   AL  159  573  104  159  25  ...
# 74863  mcgwima01    1996      1    OAK   AL  130  423  104  132  21  ...
# 75819  griffke02    1997      1    SEA   AL  157  608  125  185  34  ...
# 77063  griffke02    1998      1    SEA   AL  161  633  120  180  33  ...
# 77389  mcgwima01    1998      1    SLN   NL  155  509  130  152  21  ...
# 77736   sosasa01    1998      1    CHN   NL  159  643  134  198  20  ...
# 78705  mcgwima01    1999      1    SLN   NL  153  521  118  145  21  ...
# 79053   sosasa01    1999      1    CHN   NL  162  625  114  180  24  ...
# 80752  bondsba01    2001      1    SFN   NL  153  476  129  156  32  ...
# 81079  gonzalu01    2001      1    ARI   NL  162  609  128  198  36  ...
# 81673  rodrial01    2001      1    TEX   AL  162  632  133  201  34  ...
# 81770   sosasa01    2001      1    CHN   NL  160  577  146  189  34  ...
# 82996  rodrial01    2002      1    TEX   AL  162  624  125  187  27  ...
# 83151  thomeji01    2002      1    CLE   AL  147  480  101  146  19  ...
# 86607  jonesan01    2005      1    ATL   NL  160  586   95  154  24  ...
# 87887  howarry01    2006      1    PHI   NL  159  581  104  182  25  ...
# 88231  ortizda01    2006      1    BOS   AL  151  558  115  160  29  ...
# 89768  rodrial01    2007      1    NYA   AL  158  583  143  183  31  ...
# 92915  bautijo02    2010      1    TOR   AL  161  569  109  148  35  ...
# 97312  davisch02    2013      1    BAL   AL  160  584  103  167  42  ...
#
#          SB    CS   BB     SO   IBB   HBP    SH    SF  GIDP  rank
# 18519  14.0  14.0  150   80.0   NaN   3.0   5.0   NaN   NaN   3.0
# 19039  17.0  13.0  145   81.0   NaN   4.0   4.0   NaN   NaN   2.0
# 22256   7.0   6.0  137   89.0   NaN   0.0  14.0   NaN   NaN   1.0
# 22786   4.0   5.0  137   87.0   NaN   3.0   8.0   NaN   NaN   3.0
# 23965   3.0   NaN  105   84.0   NaN   1.0  18.0   NaN   NaN   1.0
# 24639   3.0   7.0  116   96.0   NaN   0.0   0.0   NaN   NaN   1.0
# 27752   7.0   5.0  119   92.0   NaN   3.0   3.0   NaN   NaN   1.0
# 32987   1.0   NaN   98   81.0   NaN   2.0   1.0   NaN  12.0   2.0
# 33089   2.0   NaN   74   42.0   NaN   4.0   0.0   NaN   6.0   1.0
# 34139   6.0   NaN  117   61.0   NaN   1.0   0.0   NaN  10.0   1.0
# 37819  24.0   4.0   79   60.0  13.0   4.0   0.0   7.0  12.0   2.0
# 38452  10.0   1.0  112   99.0   6.0   2.0   1.0   4.0   4.0   2.0
# 41659  12.0   1.0  126  112.0   9.0   0.0   1.0   5.0   2.0   1.0
# 41661   0.0   0.0   94   67.0   0.0   7.0   0.0   7.0  16.0   1.0
# 44642   9.0   4.0   76   71.0  16.0   0.0   2.0   2.0  11.0   1.0
# 54746   6.0   4.0   61  107.0  10.0   5.0   0.0   8.0  17.0   1.0
# 67707   0.0   1.0   90  182.0  11.0   5.0   0.0   5.0  15.0   1.0
# 74863   0.0   0.0  116  112.0  16.0   8.0   0.0   1.0  14.0   3.0
# 75819  15.0   4.0   76  121.0  23.0   8.0   0.0  12.0  12.0   1.0
# 77063  20.0   5.0   76  121.0  11.0   7.0   0.0   4.0  14.0   1.0
# 77389   1.0   0.0  162  155.0  28.0   6.0   0.0   4.0   8.0   1.0
# 77736  18.0   9.0   73  171.0  14.0   1.0   0.0   5.0  20.0   1.0
# 78705   0.0   0.0  133  141.0  21.0   2.0   0.0   5.0  12.0   2.0
# 79053   7.0   8.0   78  171.0   8.0   3.0   0.0   6.0  17.0   3.0
# 80752  13.0   3.0  177   93.0  35.0   9.0   0.0   2.0   5.0   1.0
# 81079   1.0   1.0  100   83.0  24.0  14.0   0.0   5.0  14.0   1.0
# 81673  18.0   3.0   75  131.0   6.0  16.0   0.0   9.0  17.0   3.0
# 81770   0.0   2.0  116  153.0  37.0   6.0   0.0  12.0   6.0   2.0
# 82996   9.0   4.0   87  122.0  12.0  10.0   0.0   4.0  14.0   1.0
# 83151   1.0   2.0  122  139.0  18.0   5.0   0.0   6.0   5.0   1.0
# 86607   5.0   3.0   64  112.0  13.0  15.0   0.0   7.0  19.0   1.0
# 87887   0.0   0.0  108  181.0  37.0   9.0   0.0   6.0   7.0   1.0
# 88231   1.0   0.0  119  117.0  23.0   4.0   0.0   5.0  12.0   1.0
# 89768  24.0   4.0   95  120.0  11.0  21.0   0.0   9.0  15.0   2.0
# 92915   9.0   2.0  100  116.0   2.0  10.0   0.0   4.0  10.0   1.0
# 97312   4.0   1.0   72  199.0  12.0  10.0   0.0   7.0   4.0   1.0
#
# [36 rows x 23 columns]

# %%
new = fifty.pivot_table(columns='yearID', index='playerID', values='HR')
new
# Out:
# yearID     1920  1921  1927  1928  1930  1932  1938  1947  1949  1955  ...  \
# playerID                                                               ...
# bautijo02   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# bondsba01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# davisch02   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# fieldce01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# fostege01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# foxxji01    NaN   NaN   NaN   NaN   NaN  58.0   NaN   NaN   NaN   NaN  ...
# gonzalu01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# greenha01   NaN   NaN   NaN   NaN   NaN   NaN  58.0   NaN   NaN   NaN  ...
# griffke02   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# howarry01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# jonesan01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# kinerra01   NaN   NaN   NaN   NaN   NaN   NaN   NaN  51.0  54.0   NaN  ...
# mantlmi01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# marisro01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# mayswi01    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  51.0  ...
# mcgwima01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# mizejo01    NaN   NaN   NaN   NaN   NaN   NaN   NaN  51.0   NaN   NaN  ...
# ortizda01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# rodrial01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ruthba01   54.0  59.0  60.0  54.0   NaN   NaN   NaN   NaN   NaN   NaN  ...
# sosasa01    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# thomeji01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# wilsoha01   NaN   NaN   NaN   NaN  56.0   NaN   NaN   NaN   NaN   NaN  ...
#
# yearID     1997  1998  1999  2001  2002  2005  2006  2007  2010  2013
# playerID
# bautijo02   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  54.0   NaN
# bondsba01   NaN   NaN   NaN  73.0   NaN   NaN   NaN   NaN   NaN   NaN
# davisch02   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  53.0
# fieldce01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# fostege01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# foxxji01    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# gonzalu01   NaN   NaN   NaN  57.0   NaN   NaN   NaN   NaN   NaN   NaN
# greenha01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# griffke02  56.0  56.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# howarry01   NaN   NaN   NaN   NaN   NaN   NaN  58.0   NaN   NaN   NaN
# jonesan01   NaN   NaN   NaN   NaN   NaN  51.0   NaN   NaN   NaN   NaN
# kinerra01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# mantlmi01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# marisro01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# mayswi01    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# mcgwima01   NaN  70.0  65.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# mizejo01    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ortizda01   NaN   NaN   NaN   NaN   NaN   NaN  54.0   NaN   NaN   NaN
# rodrial01   NaN   NaN   NaN  52.0  57.0   NaN   NaN  54.0   NaN   NaN
# ruthba01    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# sosasa01    NaN  66.0  63.0  64.0   NaN   NaN   NaN   NaN   NaN   NaN
# thomeji01   NaN   NaN   NaN   NaN  52.0   NaN   NaN   NaN   NaN   NaN
# wilsoha01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [23 rows x 26 columns]

# %%
noah = df[df.playerID == 'syndeno01']
noah = noah[['playerID', 'yearID', 'G', 'AB', 'H', 'HR']]
noah
# Out:
#          playerID  yearID   G  AB   H  HR
# 101170  syndeno01    2015  24  43   9   1
# 102660  syndeno01    2016  31  58  11   3

# %%
file = "zz_foo"
f = open(file, "w")
fifty = df[df.HR > 50].sort_values('HR',ascending=False)
print(fifty >> f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [13], line 4
#       2 f = open(file, "w")
#       3 fifty = df[df.HR > 50].sort_values('HR',ascending=False)
# ----> 4 print(fifty >> f)
#
# TypeError: unsupported operand type(s) for >>: 'DataFrame' and '_io.TextIOWrapper'

# %%
dfz = df['HR', 'G']
dfz
# Out:
# Running cells with 'Python 3.9.13 ('prime')' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n prime ipykernel --update-deps --force-reinstall'

# %%
# Out:
# Running cells with 'Python 3.9.13 ('prime')' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n prime ipykernel --update-deps --force-reinstall'
