# %%
import pandas as pd
import numpy as np
#import pandas_profiling

path = r"/Users/kevin.reilly/OneDrive - Learfield IMG College/repos/baseballdatabank/core/batting.csv"
# 'r' is used to elminate the whitespace in the path.

df = pd.read_csv(path)

pop = len(df)
print ("Total records:")
print (pop)
print ("")
print ("The summary stats:")
df.describe()
# Out:
# Total records:
# 110495
#
# The summary stats:
#               yearID          stint              G             AB  \
# count  110495.000000  110495.000000  110495.000000  110495.000000
# mean     1968.051948       1.079624      50.605258     138.557084
# std        39.992877       0.288199      46.831714     183.317500
# min      1871.000000       1.000000       1.000000       0.000000
# 25%      1938.000000       1.000000      12.000000       3.000000
# 50%      1977.000000       1.000000      34.000000      45.000000
# 75%      2002.000000       1.000000      78.000000     222.000000
# max      2021.000000       5.000000     165.000000     716.000000
#
#                    R              H             2B             3B  \
# count  110495.000000  110495.000000  110495.000000  110495.000000
# mean       18.397312      36.184117       6.177429       1.233893
# std        27.990668      52.066687       9.613576       2.580559
# ...

# %% [markdown]
# # Batting Average

# %%
df['avg'] = df['H'] / df['AB']
df_avg = df[['playerID', 'yearID', 'AB', 'avg']].sort_values('avg',ascending=False)
df_avg.head(10)
# Out:
#          playerID  yearID  AB  avg
# 17287   haineje01    1918   1  1.0
# 33297   whiteer01    1947   1  1.0
# 100243   dunnmi01    2015   1  1.0
# 81896   walbema01    2001   1  1.0
# 33249   swartbu01    1947   1  1.0
# 20235   altroni01    1924   1  1.0
# 501      snowch01    1874   1  1.0
# 38014   souchst01    1955   1  1.0
# 38055   thronma01    1955   2  1.0
# 21943   churrjo01    1927   1  1.0

# %%
df_avg_2 = df_avg[(df_avg.AB > 100) & (df_avg.yearID > 1900)]
df_avg_2.head(10)
# Out:
#         playerID  yearID   AB       avg
# 8335   lajoina01    1901  544  0.426471
# 20466  hornsro01    1924  536  0.423507
# 19619  sislege01    1922  586  0.419795
# 12722   cobbty01    1911  591  0.419628
# 13296   cobbty01    1912  553  0.408680
# 12879  jacksjo01    1911  571  0.408056
# 18571  sislege01    1920  631  0.407290
# 29807  willite01    1941  456  0.405702
# 38957  hazlebo01    1957  134  0.402985
# 21019  hornsro01    1925  504  0.402778

# %%
df['avg'] = df['H'] / df['AB']
df_avg = df[(df.AB > 100) & (df.yearID > 1900)].df[['playerID', 'yearID', 'AB', 'avg']].sort_values('avg',ascending=False)
df_avg.head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/g0/_fmqcb_13cn4tshlbm9x2qg5w19tkx/T/ipykernel_13657/2054273584.py in <module>
#       1 df['avg'] = df['H'] / df['AB']
# ----> 2 df_avg = df[(df.AB > 100) & (df.yearID > 1900)].df[['playerID', 'yearID', 'AB', 'avg']].sort_values('avg',ascending=False)
#       3 df_avg.head(10)
#
# ~/opt/anaconda3/envs/titanic/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'df'

# %% [markdown]
# # Selecting a Year
#
# Looking only for data on a single year.
#
# There are multiple ways to select dataframe rows based on a critira.
#
# `df[df.column_name == value]`
#
# `df.loc[df[columnname] == value]`
#
# * Determine how to select rows based on multiple criteria
# * Figure out how to add a column based on a calculation

# %%
yr = 2020

df_yr = df[df.yearID == yr]
df_yr
# Out:
#          playerID  yearID  stint teamID lgID   G   AB   R   H  2B  ...   RBI  \
# 107429  abreual01    2020      1    NYA   AL   2    0   0   0   0  ...   0.0
# 107430  abreubr01    2020      1    HOU   AL   4    0   0   0   0  ...   0.0
# 107431  abreujo02    2020      1    CHA   AL  60  240  43  76  15  ...  60.0
# 107432  acunaro01    2020      1    ATL   NL  46  160  46  40  11  ...  29.0
# 107433  adamewi01    2020      1    TBA   AL  54  185  29  48  15  ...  23.0
# ...           ...     ...    ...    ...  ...  ..  ...  ..  ..  ..  ...   ...
# 108784  zimmebr02    2020      1    BAL   AL   2    0   0   0   0  ...   0.0
# 108785  zimmejo02    2020      1    DET   AL   3    0   0   0   0  ...   0.0
# 108786  zimmeky01    2020      1    KCA   AL  16    0   0   0   0  ...   0.0
# 108787  zuberty01    2020      1    KCA   AL  23    0   0   0   0  ...   0.0
# 108788  zuninmi01    2020      1    TBA   AL  28   75   8  11   4  ...  10.0
#
# ...

# %%
team = df.loc[df['teamID'] == 'NY1']

team
# Out:
#         playerID  yearID  stint teamID lgID   G   AB   R    H  2B  ...   RBI  \
# 1685   allenmy01    1883      1    NY1   NL   1    4   0    0   0  ...   1.0
# 1721   caskied01    1883      1    NY1   NL  95  383  47   91  11  ...  40.0
# 1724   clappjo01    1883      1    NY1   NL  20   73   6   13   0  ...   5.0
# 1728   connoro01    1883      1    NY1   NL  98  409  80  146  28  ...  50.0
# 1732   cramedi01    1883      1    NY1   NL   2    6   0    0   0  ...   0.0
# ...          ...     ...    ...    ...  ...  ..  ...  ..  ...  ..  ...   ...
# 39289  thomava01    1957      1    NY1   NL  88  241  30   60  10  ...  31.0
# 39292  thomsbo01    1957      2    NY1   NL  81  215  24   52   7  ...  38.0
# 39317  virgioz01    1957      1    NY1   NL  96  226  26   53   0  ...  24.0
# 39326  westrwe01    1957      1    NY1   NL  63   91   4   15   1  ...   2.0
# 39345  worthal01    1957      1    NY1   NL  55   40   0    4   0  ...   3.0
#
# ...

# %%
df_yr["BA"] = df_yr.H / df_yr.AB

df_yr
# Out:
# <ipython-input-4-17709cbb5b8e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_yr["BA"] = df_yr.H / df_yr.AB
#          playerID  yearID  stint teamID lgID   G   AB   R   H  2B  ...   SB  \
# 107429  abreual01    2020      1    NYA   AL   2    0   0   0   0  ...  0.0
# 107430  abreubr01    2020      1    HOU   AL   4    0   0   0   0  ...  0.0
# 107431  abreujo02    2020      1    CHA   AL  60  240  43  76  15  ...  0.0
# 107432  acunaro01    2020      1    ATL   NL  46  160  46  40  11  ...  8.0
# 107433  adamewi01    2020      1    TBA   AL  54  185  29  48  15  ...  2.0
# ...           ...     ...    ...    ...  ...  ..  ...  ..  ..  ..  ...  ...
# 108784  zimmebr02    2020      1    BAL   AL   2    0   0   0   0  ...  0.0
# ...

# %%
df.RBI.describe()
# Out:
# count    109739.000000
# mean         16.720664
# std          26.187532
# min           0.000000
# 25%           0.000000
# 50%           3.000000
# 75%          24.000000
# max         191.000000
# Name: RBI, dtype: float64

# %%
rbi = df.RBI.max()
rbi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0de36fc2b019> in <module>
# ----> 1 rbi = df.RBI.max()
#       2 rbi
#
# NameError: name 'df' is not defined

# %%
df.HR.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
fifty = df[df.HR > 50]
#fifty[['playerID', 'yearID', 'HR']].sort_values('HR',ascending=False)
fifty
# Out:
#          playerID  yearID  stint teamID lgID    G   AB    R    H  2B  ...  \
# 18533    ruthba01    1920      1    NYA   AL  142  457  158  172  36  ...
# 19053    ruthba01    1921      1    NYA   AL  152  540  177  204  44  ...
# 22270    ruthba01    1927      1    NYA   AL  151  540  158  192  29  ...
# 22800    ruthba01    1928      1    NYA   AL  154  536  163  173  29  ...
# 23979   wilsoha01    1930      1    CHN   NL  155  585  146  208  35  ...
# 24653    foxxji01    1932      1    PHA   AL  154  585  151  213  33  ...
# 27766   greenha01    1938      1    DET   AL  155  556  144  175  23  ...
# 33001   kinerra01    1947      1    PIT   NL  152  565  118  177  23  ...
# 33103    mizejo01    1947      1    NY1   NL  154  586  137  177  26  ...
# 34153   kinerra01    1949      1    PIT   NL  152  549  116  170  19  ...
# 37833    mayswi01    1955      1    NY1   NL  152  580  123  185  18  ...
# 38466   mantlmi01    1956      1    NYA   AL  150  533  132  188  22  ...
# ...

# %%
fifty["rank"] = fifty.groupby("playerID")["HR"].rank("dense", ascending=False)
fifty
# Out:
# <ipython-input-9-97b0e3d1bfd3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fifty["rank"] = fifty.groupby("playerID")["HR"].rank("dense", ascending=False)
#          playerID  yearID  stint teamID lgID    G   AB    R    H  2B  ...  \
# 18533    ruthba01    1920      1    NYA   AL  142  457  158  172  36  ...
# 19053    ruthba01    1921      1    NYA   AL  152  540  177  204  44  ...
# 22270    ruthba01    1927      1    NYA   AL  151  540  158  192  29  ...
# 22800    ruthba01    1928      1    NYA   AL  154  536  163  173  29  ...
# 23979   wilsoha01    1930      1    CHN   NL  155  585  146  208  35  ...
# 24653    foxxji01    1932      1    PHA   AL  154  585  151  213  33  ...
# ...

# %%
new = fifty.pivot_table(columns='yearID', index='playerID', values='HR')
new
# Out:
# yearID     1920  1921  1927  1928  1930  1932  1938  1947  1949  1955  ...  \
# playerID                                                               ...
# alonspe01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# bautijo02   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# bondsba01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# davisch02   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# fieldce01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# fostege01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# foxxji01    NaN   NaN   NaN   NaN   NaN  58.0   NaN   NaN   NaN   NaN  ...
# gonzalu01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# greenha01   NaN   NaN   NaN   NaN   NaN   NaN  58.0   NaN   NaN   NaN  ...
# griffke02   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
noah = df[df.playerID == 'syndeno01']
noah = noah[['playerID', 'yearID', 'G', 'AB', 'H', 'HR']]
noah
# Out:
#          playerID  yearID   G  AB   H  HR
# 101185  syndeno01    2015  24  43   9   1
# 102675  syndeno01    2016  31  58  11   3
# 104156  syndeno01    2017   7   9   2   0
# 105681  syndeno01    2018  25  47   6   0
# 107246  syndeno01    2019  32  65   6   2
# 110280  syndeno01    2021   2   0   0   0

# %%
file = "zz_foo"
f = open(file, "w")
fifty = df[df.HR > 50].sort_values('HR',ascending=False)
print(fifty >> f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-cd17ea76985e> in <module>
#       2 f = open(file, "w")
#       3 fifty = df[df.HR > 50].sort_values('HR',ascending=False)
# ----> 4 print(fifty >> f)
#
# TypeError: unsupported operand type(s) for >>: 'DataFrame' and '_io.TextIOWrapper'

# %%
dfz = df['HR', 'G']
dfz
