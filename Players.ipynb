# %%
import pandas as pd
import numpy as np

path = r"/Users/kevin.reilly/Library/CloudStorage/OneDrive-TheTradeDesk/repos/baseballdatabank/core/Batting.csv"
# 'r' is used to elminate the whitespace in the path.

df = pd.read_csv(path)

pop = len(df)
print ("Total records:")
print (pop)
print ("")
print ("The summary stats:")
df.describe().T
# Out:
# Total records:
# 110495
#
# The summary stats:
#            count         mean         std     min     25%     50%     75%  \
# yearID  110495.0  1968.051948   39.992877  1871.0  1938.0  1977.0  2002.0
# stint   110495.0     1.079624    0.288199     1.0     1.0     1.0     1.0
# G       110495.0    50.605258   46.831714     1.0    12.0    34.0    78.0
# AB      110495.0   138.557084  183.317500     0.0     3.0    45.0   222.0
# R       110495.0    18.397312   27.990668     0.0     0.0     4.0    26.0
# H       110495.0    36.184117   52.066687     0.0     0.0     8.0    55.0
# 2B      110495.0     6.177429    9.613576     0.0     0.0     1.0     9.0
# 3B      110495.0     1.233893    2.580559     0.0     0.0     0.0     1.0
# HR      110495.0     2.859939    6.386896     0.0     0.0     0.0     2.0
# RBI     109739.0    16.720664   26.187532     0.0     0.0     3.0    24.0
# SB      108127.0     2.893190    7.564655     0.0     0.0     0.0     2.0
# CS       86954.0     1.162431    2.662906     0.0     0.0     0.0     1.0
# BB      110495.0    12.787556   20.555314     0.0     0.0     2.0    18.0
# SO      108395.0    20.625038   28.724308     0.0     1.0     9.0    29.0
# IBB      73845.0     1.040368    2.688349     0.0     0.0     0.0     1.0
# HBP     107679.0     1.060810    2.299942     0.0     0.0     0.0     1.0
# SH      104427.0     2.168529    4.129955     0.0     0.0     0.0     3.0
# SF       74392.0     1.014800    1.923280     0.0     0.0     0.0     1.0
# GIDP     85054.0     2.874586    4.658673     0.0     0.0     0.0     4.0
#
#            max
# yearID  2021.0
# stint      5.0
# G        165.0
# AB       716.0
# R        198.0
# H        262.0
# 2B        67.0
# 3B        36.0
# HR        73.0
# RBI      191.0
# SB       138.0
# CS        42.0
# BB       232.0
# SO       223.0
# IBB      120.0
# HBP       51.0
# SH        67.0
# SF        19.0
# GIDP      36.0

# %%
df.dtypes
# Out:
# playerID         object
# birthYear       float64
# birthMonth      float64
# birthDay        float64
# birthCountry     object
# birthState       object
# birthCity        object
# deathYear       float64
# deathMonth      float64
# deathDay        float64
# deathCountry     object
# deathState       object
# deathCity        object
# nameFirst        object
# nameLast         object
# nameGiven        object
# weight          float64
# height          float64
# bats             object
# throws           object
# debut            object
# finalGame        object
# retroID          object
# bbrefID          object
# dtype: object

# %%
df['nameFirst'].astype(str)
# Out:
# 0         David
# 1          Hank
# 2        Tommie
# 3           Don
# 4          Andy
#           ...
# 20365     Frank
# 20366      Paul
# 20367    George
# 20368     Dutch
# 20369      Tony
# Name: nameFirst, Length: 20370, dtype: object

# %%
name_set = {'Reid'}
players = df.loc[df['nameFirst'].isin(name_set)]

players
# Out:
#         playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 2038   brignre01     1986.0         1.0      16.0          USA         LA
# 3733   cornere01     1970.0         6.0       2.0          USA         AL
# 4566   detmere01     1999.0         7.0       8.0          USA         IL
# 6897   gorecre01     1980.0        12.0      22.0          USA         NY
# 13337  nichore01     1958.0         8.0       5.0          USA         FL
#
#          birthCity  deathYear  deathMonth  deathDay  ...   nameLast  \
# 2038     St. Amant        NaN         NaN       NaN  ...    Brignac
# 3733   Thomasville        NaN         NaN       NaN  ...  Cornelius
# 4566       Nokomis        NaN         NaN       NaN  ...    Detmers
# 6897        Queens        NaN         NaN       NaN  ...    Gorecki
# 13337        Ocala        NaN         NaN       NaN  ...    Nichols
#
#            nameGiven weight height bats throws       debut   finalGame  \
# 2038    Reid Michael  197.0   74.0    B      R  2008-07-04  2016-05-26
# 3733   Jonathan Reid  200.0   72.0    R      R  1995-04-29  2000-09-30
# 4566   Reid Kristien  210.0   74.0    L      L  2021-08-01  2021-10-03
# 6897       Reid Evan  200.0   73.0    R      R  2009-08-17  2009-10-04
# 13337    Thomas Reid  165.0   71.0    R      R  1980-09-16  1987-10-04
#
#         retroID    bbrefID
# 2038   brigr001  brignre01
# 3733   cornr001  cornere01
# 4566   detmr001  detmere01
# 6897   gorer002  gorecre01
# 13337  nichr001  nichore01
#
# [5 rows x 24 columns]

# %%
playerID = {'gorecre01'}

stats = df.loc[df['playerID'].isin(playerID)]
stats
# Out:
#        playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 6897  gorecre01     1980.0        12.0      22.0          USA         NY
#
#      birthCity  deathYear  deathMonth  deathDay  ... nameLast  nameGiven  \
# 6897    Queens        NaN         NaN       NaN  ...  Gorecki  Reid Evan
#
#      weight height bats throws       debut   finalGame   retroID    bbrefID
# 6897  200.0   73.0    R      R  2009-08-17  2009-10-04  gorer002  gorecre01
#
# [1 rows x 24 columns]
